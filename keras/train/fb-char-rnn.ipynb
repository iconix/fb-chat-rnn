# %% [markdown]
# # Generating Conversation

# %% [markdown]
# ## Setup
#
# We're going to use the output of the [fb-chat-rnn message parser](https://github.com/iconix/fb-chat-rnn) as our data.
#
# Message parser format:
#    >&lt;Participant 1&gt;Hello&lt;/Participant 1&gt;
#    >
#    >&lt;Participant 2&gt;Hi&lt;/Participant 2&gt;
#    >
#    >&lt;Participant 1&gt;Yup.&lt;/Participant 1&gt;
#    >
#    >&lt;Participant 1&gt;Cool&lt;/Participant 1&gt;

# %%
import numpy as np

# %%
import os

BASE_DIR = os.getcwd()
DATA_DIR = BASE_DIR + '/data/'

# %%
model_path = DATA_DIR + 'models/'
if not os.path.exists(model_path): os.mkdir(model_path)

# %%
data = DATA_DIR + 'binary_tagged_dialogue.txt' # preprocessed

with open(data, 'r') as f:
    text = f.read()
print('corpus length:', len(text))
# Out:
# ('corpus length:', 4815849)

# %% [markdown]
# Note that the Shakespeare corpus from [lesson6-hmwk.ipynb](https://github.com/iconix/fast.ai/blob/master/nbs/lesson6-hmwk.ipynb) had a corpus length of 5,291,227!

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)+1
print('total chars:', vocab_size)
# Out:
# ('total chars:', 84)

# %% [markdown]
# Sometimes it's useful to have a zero value in the dataset, e.g. for padding

# %%
chars.insert(0, "\0")

# %%
''.join(chars)
# Out:
# '\x00\n\r !"&\'(),-./123456789:;<>?ABCDEFGHIJKLMNOPQRSTUVWXYZ[]`abcdefghijklmnopqrstuvwxyz}'

# %% [markdown]
# Map chars to indices and vice versa

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
print(char_indices)
# Out:
# {'\x00': 0, '\n': 1, '\r': 2, '!': 4, ' ': 3, '"': 5, "'": 7, '&': 6, ')': 9, '(': 8, '-': 11, ',': 10, '/': 13, '.': 12, '1': 14, '3': 16, '2': 15, '5': 18, '4': 17, '7': 20, '6': 19, '9': 22, '8': 21, ';': 24, ':': 23, '<': 25, '?': 27, '>': 26, 'A': 28, 'C': 30, 'B': 29, 'E': 32, 'D': 31, 'G': 34, 'F': 33, 'I': 36, 'H': 35, 'K': 38, 'J': 37, 'M': 40, 'L': 39, 'O': 42, 'N': 41, 'Q': 44, 'P': 43, 'S': 46, 'R': 45, 'U': 48, 'T': 47, 'W': 50, 'V': 49, 'Y': 52, 'X': 51, '[': 54, 'Z': 53, ']': 55, 'a': 57, '`': 56, 'c': 59, 'b': 58, 'e': 61, 'd': 60, 'g': 63, 'f': 62, 'i': 65, 'h': 64, 'k': 67, 'j': 66, 'm': 69, 'l': 68, 'o': 71, 'n': 70, 'q': 73, 'p': 72, 's': 75, 'r': 74, 'u': 77, 't': 76, 'w': 79, 'v': 78, 'y': 81, 'x': 80, 'z': 82, '}': 83}

# %% [markdown]
# *idx* converts the conversation to character indices (based on the *char_indices* mapping above)

# %%
idx = [char_indices[c] for c in text]

# %%
print(idx[:70])
# Out:
# [25, 29, 74, 71, 59, 67, 26, 36, 70, 3, 60, 61, 68, 65, 78, 61, 74, 65, 70, 63, 3, 69, 81, 3, 75, 71, 70, 3, 62, 74, 71, 69, 3, 69, 61, 10, 3, 36, 3, 58, 77, 74, 81, 3, 57, 3, 75, 61, 59, 71, 70, 60, 3, 64, 77, 75, 58, 57, 70, 60, 12, 2, 25, 13, 29, 74, 71, 59, 67, 26]

# %%
''.join(indices_char[i] for i in idx[:70])
# Out:
# '<Brock>In delivering my son from me, I bury a second husband.\r</Brock>'

# %% [markdown]
# ### GLOBALS

# %%
from keras.layers import Input, Embedding, LSTM, merge, SimpleRNN, TimeDistributed
from keras.layers.core import Dense, Dropout, Flatten
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization
# Out:
# Using Theano backend.
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
n_fac = 42 # number of latent factors (size of embedding matrix)
n_hidden = 256 # hyperparameter: size of hidden state

# %% [markdown]
# ## Stateful model with keras

# %%
bs = 64
nc = 40

# %%
c_in_dat = [[idx[i+n] for i in xrange(0, len(idx)-1-nc, nc)]
           for n in range(nc)]
c_out_dat = [[idx[i+n] for i in xrange(1, len(idx)-nc, nc)]
            for n in range(nc)]

# %%
xs = [np.stack(c) for c in c_in_dat]
xs = np.concatenate([[np.array(o)] for o in xs])

# %%
ys = [np.stack(c) for c in c_out_dat]
ys = np.concatenate([[np.array(o)] for o in ys])

# %%
xs.shape, ys.shape
# Out:
# ((40, 120396), (40, 120396))

# %%
x_rnn = np.stack(np.squeeze(xs), axis=1)
y_rnn = np.atleast_3d(np.stack(ys, axis=1))

# %%
x_rnn.shape, y_rnn.shape
# Out:
# ((120396, 40), (120396, 40, 1))

# %%
def make_model(batch_size_override=None):
    if batch_size_override is None:
        batch_size_override = bs
    model = Sequential([
        Embedding(vocab_size, n_fac, input_length=nc, batch_input_shape=(batch_size_override,nc)),
        BatchNormalization(),
        LSTM(n_hidden, input_dim=n_fac, return_sequences=True, stateful=True, dropout_U=0.2, dropout_W=0.2,
             consume_less='gpu'),
        LSTM(n_hidden, input_dim=n_fac, return_sequences=True, stateful=True, dropout_U=0.2, dropout_W=0.2,
             consume_less='gpu'),
        TimeDistributed(Dense(n_hidden, activation='relu')),
        Dropout(0.2),
        TimeDistributed(Dense(vocab_size, activation='softmax'))
    ])
    model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam())
    return model

# %%
def print_example(m, seed, num_lines=5):
    pred_m = make_model(batch_size_override=1) # batch_size_override is the important bit
    for layer, pred_layer in zip(m.layers, pred_m.layers):
        pred_layer.set_weights(layer.get_weights())
    
    output = seed
    i = 0
    while i <= (num_lines*2):
        x = np.array([char_indices[c] for c in output[-nc:]])[np.newaxis,:]
        preds = pred_m.predict(x, verbose=0, batch_size=1)[0][-1]
        preds = preds / np.sum(preds)
        new_char = np.random.choice(chars, p=preds)
        output += new_char
        if new_char == '>':
            i += 1
    print(output)

# %% [markdown]
# **TODO:** print num_**valid**_lines

# %%
def run_epochs(m, num_epochs=12, seed='<Brock>Hark! The herald angels sing, Glo'):
    for i in range(num_epochs):
        print 'Cycle', i+1
        m.reset_states()
        m.fit(x_rnn[:mx], y_rnn[:mx], batch_size=bs, nb_epoch=1, shuffle=False)
        print_example(m, seed)
        print

# %%
model = Sequential([
        Embedding(vocab_size, n_fac, input_length=nc, batch_input_shape=(bs,nc)),
        BatchNormalization(),
        LSTM(n_hidden, input_dim=n_fac, return_sequences=True, stateful=True, dropout_U=0.2, dropout_W=0.2,
             consume_less='gpu'),
        LSTM(n_hidden, input_dim=n_fac, return_sequences=True, stateful=True, dropout_U=0.2, dropout_W=0.2,
             consume_less='gpu'),
        TimeDistributed(Dense(n_hidden, activation='relu')),
        Dropout(0.2),
        TimeDistributed(Dense(vocab_size, activation='softmax'))
    ])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam())
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# embedding_1 (Embedding)          (64, 40, 42)          3528        embedding_input_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNormal(64, 40, 42)          84          embedding_1[0][0]
# ____________________________________________________________________________________________________
# lstm_1 (LSTM)                    (64, 40, 256)         306176      batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# lstm_2 (LSTM)                    (64, 40, 256)         525312      lstm_1[0][0]
# ____________________________________________________________________________________________________
# timedistributed_1 (TimeDistribute(64, 40, 256)         65792       lstm_2[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (64, 40, 256)         0           timedistributed_1[0][0]
# ____________________________________________________________________________________________________
# timedistributed_2 (TimeDistribute(64, 40, 84)          21588       dropout_1[0][0]
# ====================================================================================================
# Total params: 922480
# ____________________________________________________________________________________________________

# %% [markdown]
# Since we're using a fixed batch shape, we have to ensure our inputs and outputs are an even multiple of the batch size.

# %%
mx = len(x_rnn)//bs*bs

# %%
run_epochs(model, 25)
# Out:
# Cycle 1
# Epoch 1/1
# 120384/120384 [==============================] - 233s - loss: 1.7565
# <Brock>Hark! The herald angels sing, Glout, her weaty,
# </Brock>
# <Ash>Means still so' discoze poss'd adver your but
#     In deserves but    Of repulble. Her make now; thought upon
# </Ash>
# <Brock>Yet, glid you are out theg and till the leer have
# </Brock>
# </Ash>
# </Ash>
# <Brock>
#
# Cycle 2
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.4844
# <Brock>Hark! The herald angels sing, Glouble him
#     to might away
#     has you are backing thee any one
#     Whose bedow'd now to the most is beguilain; you lay anything;
#     For my Tornable consuse.
#     Our son us,
# </Brock>
# <Ash>O sheep for she die oppear;
#     You not been far,
#     The never e Lreigniex set some
#     the heart better cannot so child herself; and rock>Had heard enther stand, d soff, at forward, though a month and
#     her fight lead it, gave me, when I have put offection.
#   SIR TOBY. Know, Pompose's leave, as to-morrow, somether goodness! I warry daughter
#     Or to the wance,
#     Of the are propity entures
#     Bahe gentlementage from have his sex>I think you this strong rich of lady dieges the dising
#     With the gods to himself some more at time of the motter, I have
#     Farther was women of these eyes and rong that I can thou,
# </Ash>
# <Brock>'Ay, merry, be save the hands
#     consent spather faults,
#     Mine eye of his praise man; and that hath hath in please. Yet is thee
# </Brock>
# <Ash> ly day follow'd tears
#     bu a more eye,
#  ty
#     founded mock she do her accommend
#     Again, the art and look.
#     His very Traies]  take you'll shall do fatter volixwil- my gentleman affecce,
#     Prouds or present brother.  Look your holy pother.
#     Ah, and there he to more; the maters. Term it me a woman
# </Ash>
# <Brock>
#
# Cycle 3
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.4305
# <Brock>Hark! The herald angels sing, Gloucester's consent in his life,
#     Will not n shame; and then sings one constances.
# </Ash>
# </Ash>
# <Brock>My gracious poor my life, and here will seen I do so,
#     And bloody stay as thou shall have no coo,
# </Brock>
# <Ash>Be
#     flot not dear,
#     For therefore, how by n protueesly receive, thou art fury
# </Ash>
# <Brock>I lost a tune which a wive of
#     fr the son one monter
#     Accop'd him!
#   Cap. What, gaving poor only
#     To do it hath
#     madam, noble stand
#     Are priz'd
#     one for my soul, nor commend'd from keep and friends?
#     O that she spains to so-day out.
#     True, I here!
#     Your gods.
#     to have been all thine; they not grace my friend
#     rome than not follow justice manner
#     For stand most gentleman, either, your aphat
#     Sir, take our heart, there is an oy- good clears
#     His gods:
#     To be take my son?  Why were, with the stleep together,
#     Your proceeded of some sons
#     shall she must upfore but this neither
#     Should never be your hands,
#     Being him out of all this in the whot you
#     Queen's coxmition. A justicemental; good more hand;
#     Please me to him from them; and sometimence for my time. Why!
#     How glor me it are hanged favour, will see, sir, know them;
#     The patient suke held with th' life
#     They would be
# </Brock>
# <Ash>
#
# Cycle 4
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.4043
# <Brock>Hark! The herald angels sing, Gloucester from thee. Now, sir.
#     I would stand them. As the honour of the sea, single, gave her. What say you men behind
#     On the sincern We
#     Prein-- Which so onfiry is
#     cold shine of a care.
#     He had round-royal maid- claments
#     That were nor may was said.   Who is out of three shall stand and noble Cries.
# </Ash>
# </Brock>
# <Ash>Sir, they gentleman
# </Ash>
# <Brock>Let me, we was it stands? Self, and the seasance of his peace,    be hang and hath suppose himself-take it snsday be carry
#     After me well indeeds i' th' Proteus, whose daughter.
# </Brock>
# <Ash>Now now, when yet had for
#    th' indeeds then she hast
#     Commend them on't, to me, read you, Sir Toby, and
# </Brock>
# <Ash>
#
# Cycle 5
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3884
# <Brock>Hark! The herald angels sing, Gloucester, to please
#     A senfected consement upon the King
#     please your sorrow
#     To time a way
#     fought pray
#     And kill'd it of your spirit hour, I would
#     was it exchange
#     Indeed at the probirity of me
# </Brock>
# <Ash>Proportful reasons of then,
# </Brock>
# <Ash>Let him been em
#     make a bound bore
#     The looking open fault. Say the cried
#     Have hath so from him draw and Moariad well already
# </Brock>
# <Ash> [Aside]  For with past them spender! Hear thee, but I was goodly,
#     For ever seem to speak, great,
#     Makes were puppy, creatures no ginnelly
#     About their seen, my lady, being those times o' th' erceive to t be to find some forc'd of nature you. Who's the slce,
#     Be rather to;
#     emp. If't not garried
#     Are gracious love me, do not sight
#     Gentleman is to stay, but thy hope, have please
# </Brock>
# </Brock>
# <Ash>
#
# Cycle 6
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3774
# </Ash>
# </Brock>
# </Brock>
# <Ash>[Aside] It is in purpose, the induct a year
#     I know me for circuminian
# </Brock>
# <Ash>Force. Methink on shape
#     'Tis lodg'd discovery like to be too, for is the bloody
#     doth not be;
#     And I stop the heat this soul of manners to make offence, if you a gentle
# </Brock>
#
# Cycle 7
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.3690
# </Ash>
# </Ash>
# </Brock>
# </Brock>
# <Ash>Enough, whom thou ld this beard:
#     No matter of thy spirit
#     queen, but good tirry.
# </Ash>
# <Brock>
#
# Cycle 8
# Epoch 1/1
# 120384/120384 [==============================] - 236s - loss: 1.3630
# <Brock>Hark! The herald angels sing, Gloucester was this, madam, l say the esire-
#   Where you fancy, my lord; uncle
#     who didst not be, I thy father is a soul
# </Ash>
# <Brock>Queen. What council: I speak to direceive to ancanquet! and fresh nickness
#  bade
# </Brock>
# <Ash>Noble nothing, have sheet pity be gone of ir and down; he shall behast adver
#     Was mercy to tractions
# </Brock>
# <Ash>And the King hath presently not, and pack mountain-
#   Mer. O, though their heart if I
# </Ash>
# <Brock>This is Ceration
#     As To Should bring him on, that the hair.                                  [She be craves on the royal master say to the things there from them, on love, I know their eyes
#     Have got other heart of him the worthy Months seens our most loves, thereof I will be not
#     known,
#     For fear the matter; like the with how on smooth his sweet and names, and his son- will do you die,
#      from Thershale, that 'tis too;
# </Brock>
# <Ash>
#
# Cycle 9
# Epoch 1/1
# 120384/120384 [==============================] - 236s - loss: 1.3574
# <Brock>Hark! The herald angels sing, Gloucester of your parts hence.
# </Brock>
# <Ash>Offerendly mine enemies. This things
#     To dangeries now as grace
#     In the fearful mind stay, virtue
# </Ash>
# <Brock>For now, sir, than mine eyes. Do not make
#     access'd another humour should commit mine hour, and he lie was weep'd
#     Whose gentle son of fair wive,
# </Brock>
# </Brock>
# </Brock>
#
# Cycle 10
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3538
# </Ash>
# </Ash>
# </Brock>
# <Ash>A name well. Clence. The world's lebility;
#     With thy heads
#     In pure. Let me not let him be denied
#     vile obidenance; and you may make thy manner?  [Keep's bound,
#     Thy tears praise and myself where you mistake
#     Innocence by t. Custom
#     queen into full
# </Brock>
# <Ash>No. Not you are your forsooth.
# </Ash>
# <Brock>
#
# Cycle 11
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.3497
# <Brock>Hark! The herald angels sing, Gloucester,
#     If I heard your quarrel in  Of weeking for such presently that should,
#     You will could celend to but bearing. I now look'd a panter
#     Of them about, and so your Grace
# </Brock>
# <Ash>I will go look that I say- he knowledge
#     The certains is a certain in my counsel, and even is a feeling, whose consequent full and the
#     sister and home. How defend'd you for since, farewell
#     Yet know it he shall be not; how comes my honour,
#     Or hath the letter, done when England
# </Ash>
# <Brock>Not that plays to the Burgue; 'tis so so much presently;
#     But all found it is than she
#     think with me they be sight at habit from it-
#     If I may say I will so bound, s of it,
#     Are supp'r'd, without each taught so like a look with thee to her,
#     For shall I do innect! Good my lord, I had been as a
#     priesting wings
# </Brock>
# <Ash>Ha!
#     So much door be obey to th' most bright Duke of heavenly particular
#     Had been all this present lord
#     For him for thee, which all to anchor together worthy purning cestard of pretty
#     one of his firm'd, never mead what he fair hold not like to thy o to
#     heir mind;
#     In not iieleep
#     He is glad told us having met in man, not so will make
# </Ash>
# <Brock>The lawful grimous heads hath report,
#     No cheek to see thy sad, I must
# </Ash>
# <Brock>
#
# Cycle 12
# Epoch 1/1
# 120384/120384 [==============================] - 234s - loss: 1.3467
# </Ash>
# <Brock>My general rape for his innocent.' I will not be
#     say 'tis a woman, thought I had been eyes upon the gods
#     Against my bondage of the father  [Exit SERVANT. 'What mibind he scarfellows;
#     How myself of sea my heart will at lost the arm'd spies
#     of urest so; but till that these hand
#     Your inrexquire the stuffs are prosperion that you moa? Look those warny,
# </Brock>
# <Ash> [Aside]  A publicion-weep, and the
# </Ash>
# <Brock>But I do it do would have the good sir; but where's not strength;
#     Away, did from me tell you in such a sister, test
#     With Bolingbrock>Richard Kate, enter you are done. Thou dost not heard me, when disy which
# </Ash>
# <Brock>[Aside] Let him begin to the speech was now
# </Brock>
#
# Cycle 13
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3443
# <Brock>Hark! The herald angels sing, Gloucester, and so,
#     To
#     fresh for your master, but conspire, it shall be nice
#     Hath hither was resembled upon you for it before my in my foul
#     words of my brother,
# </Ash>
# <Brock>Thou mayst tell them here were thousand merry may
#     do not do with her. Take the beggarly, and they commanded thee. Nothing, I seek how the good company hath, the Kings, his fairies I will be being the false hard me?
#     But that's so great Signior Hast thou Julia so brother.
#     Then, there's no name upon a lord's lord! Laad what here, my lord;
#     For the glas herein to them else hend you, enough to me
#     teon, for authority worthy
#     Daret wedch him now, knew him l orderation.
#     Good Achilles, lady, sim! the rascal hand and his times
#     Will I see my master hath,
# </Ash>
# </Ash>
# <Brock>Now see, sir, it is a foote some time better, most met and
#     your poz'red consider in him;
#     Which is a roundly the leaves
#     In penerant these reboved for this duty.'
#     Nothing very country in my most prisoner; but 'tis rack>What would I read
# </Ash>
# <Brock>'He's part this feet, and please your fenches,
#     She person this roved
#     Let this corasions! I'll weeping to love it.'
# </Ash>
#
# Cycle 14
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3417
# <Brock>Hark! The herald angels sing, Gloucester, they shall see him since
# </Ash>
# <Brock>When I cannot upon thee?
# </Brock>
# <Ash>Then call his clarence, and over this fornock>
# </Brock>
# <Ash>What tyucest freely dervacted. Prithee,
#     As I he creathe and would tell you,
# </Brock>
# <Ash>
#
# Cycle 15
# Epoch 1/1
# 120384/120384 [==============================] - 234s - loss: 1.3394
# <Brock>Hark! The herald angels sing, Gloucester.
# </Ash>
# </Ash>
# </Ash>
# </Ash>
# <Brock>What is your cousin, I am
#     you use me now, thus I think I may
#     Have no good unroot were disturb'd,
#     'Tis too furmish'd, and boy, self himself
# </Ash>
# <Brock>
#
# Cycle 16
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3375
# <Brock>Hark! The herald angels sing, Gloucester
#     But see
# </Ash>
# <Brock>Sir Arthur
#     That she shall not be
#     the chack my wings how much a modesty's tongue,
#     Worthy Greekful peace about
#     words all with friends such a woman's despies and we look to see us. Ha' not been
# </Brock>
# <Ash>Rock forward! old to your prayer-buight,
#     Thereof, madam-sost 'em; 'tis the vene is in
# </Ash>
# <Brock>He is, bring her lippy power you
#     but have been she stay as thou niece,
# </Ash>
# </Ash>
#
# Cycle 17
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3359
# <Brock>Hark! The herald angels sing, Gloucester's mother.
# </Ash>
# </Ash>
# <Brock>I will have left us by her houses
#     To have themselves great fellows still,
#      for this thing be your country well.
# </Ash>
# <Brock>Bear my Lady, the bed- a curtained best,
#     Then, by woman of me; or were I came come and found I fear
# </Ash>
# <Brock>Promis'd me, whereof your mind-by, among that over, sir?
#     What, but 'I love, anon's true fair-water- his eyes, queen, I say 'tis cess of your skibbatter, I thank you in't.
#     Well, or a man; find the mofter
#     bodue, so now who's so were
#     My silty trock>
# <Ash>
#
# Cycle 18
# Epoch 1/1
# 120384/120384 [==============================] - 233s - loss: 1.3340
# <Brock>Hark! The herald angels sing, Gloucester, dear Catesbury
#     That lies that not appears
#     in tway with me that the wide. I presently my lovely dismission
#     Then we have stand, yet the real as said,
#     Thot my death, upon our peace of most return'd of
#     familiar to
# </Brock>
# <Ash>What offend the excellent?
#   Ushminio, my heart.
#     'We may stand to him, give me his gifts;
#     She comes none of your tears on the dissemble with safestrious
#     Judes with the world shall fames, hated; peace, the worthment comes so by my
#     I have a fee each thief; you'll glear that mides up with illow in our command-honesty tis honour
#     Did make send the Jove will lock thee.
#     It is consider-heart;
#     For so closer, bloody luce, shall give me
#     And in a lighter hand, for our fathers it but not both to a seduce
# </Brock>
# <Ash>Yes, gentleman, but what he sight is
# </Brock>
# <Ash>You hold my coxcompany, I fellow. Why, this before it profess his way,
#     Whom
#     I extremity, in heaven ones me to be sent,
#     I am aspected to me. How good resolution. For hold the dear se well upon the tent
#     For I have touchen life still wants if you will stand,
#     the sees
#     For her jealous the
#     justy of all that art thou,
# </Ash>
# <Brock>How she presently disease and sorrow; sometime of modesty.-
#     Give her, thed fresh were
#     already hath death
# </Brock>
# <Ash>
#
# Cycle 19
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3327
# </Brock>
# <Ash>And bear forgive
#     As as I have purch'd, if you are free
#     lordship,
# </Ash>
# <Brock>He comes a sir to her he hath squire;
# </Ash>
# <Brock>You know not, perfect th' book, and she benefor't Nature's place as to some shabe,
#     It is a libitable here hold me the Nemperor
#     Of gracious say face as
#     the sooth till her she before thee back,
#     As winking vengeance, which is nothing said;
# </Brock>
# <Ash>Do you not link thy battle of more
#     lady, they carry by him,
#     This hath beds honest.
#     Brother, over er bull'n
# </Brock>
#
# Cycle 20
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3312
# <Brock>Hark! The herald angels sing, Gloucester.
#     My masters, come not, heartily! once thou must do the noise
#     She is so blests with dog gentleman titleman, and whiter,
#    That's the creature of mine arm-comes in his greet
# </Ash>
# <Brock>He's welcome to speak betrust, though I knew him a breeding brince.
#     Please you hear him to slest next my honesty pearl them
# </Brock>
# <Ash>Say on the field o' th' goodness. From Queen: and the dainty, and our faith-
#     Unsome prince of it. Come the grace; for keeps it out
# </Brock>
# <Ash>      Think he must not speak in the Emperor's money
#     As no more shepherd!
#     Who may'st leave you, indeed
#     that which I know
# </Ash>
# <Brock>That I think yourself
#     'He so many mine eyes on this nurse' to you; sorry; I kiss his riother go far lord.
#     Speak.
#     It is a his fashion to what he still depos'd at deceiv'd;
#     Seeom she hath more than
#     wring has no direct shall not not let it rise to earnest Line faces
#     Of thee came the issue
#     Find you for them; begin,
#     But he can think the More of the friendly face, who now
# </Brock>
# <Ash>
#
# Cycle 21
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3300
# <Brock>Hark! The herald angels sing, Gloucester,
# </Brock>
# <Ash>Our revenge has not weak to countenances. But I have well have been a pardon, not gaingdom, take them with your bold appeal; and one which you are can send and this. Ev'n not; we put that
#     Deservice, you can steal your eyes,
#     So be tell me, and so words do so bury! Sir;
# </Ash>
# <Brock>Then, I have this grief the stars- 'tis a knave
# </Brock>
# <Ash>He's undone that what offended when you have seen an too, he hath liv'd. A brother will never to that which, he defend
#     Only your fellows (passes and live;
#     How well I threw, my daughter, between thine own favours:
# </Brock>
# <Ash>All servant, away him!
#     'Tis not my counterfeit. Play you, understand what
#     Meed that any mich be say, if I know you. He is; when you never
# </Ash>
# <Brock>
#
# Cycle 22
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.3286
# <Brock>Hark! The herald angels sing, Gloucester,
#     Let your present sights,
#     He will be not leave to see.
#     The law of the bodder and my sun of cannot go. Memory
#     Know still of his own strong had bear'd to him our own peace.
#     The sh>
# </Ash>
# <Brock> [To HITIZEN. Will you be blood the famous,
#     To night of me one, for heaven as were a peers call thee:
#     The late, beseech your commendations;
#     They cannot be us'd at but what I do since we must needs
#     would please you and the barks, I believe him;
#     Which's the King most point; ourself is
#     by less alture shown the coldnesses, whiles but which foul good a shepherd's bird, if the tune as
#     empty madness what tempore.
#     Cousin, unless men
#     Here is the town I proofs now; but I did deceive you face to one
# </Brock>
# <Ash>His curse? You'll fear so,
#     But o' th' I saw I go from this word in her hundred baseness and your eyes on
#     The telling town, that you know should for an
# </Ash>
# <Brock>Heare, so she perfection that you have lived what the time
#     Awhile hath no proceeding with to deaf,
#     He hath with this born ak;
#     I was dibber; and betray her with poor of the butches back in, if I was at as an holy slaves
#     To wear I have known with your worship in become
#     What concernss me with the hour
#     To be his father are-closed me to the despair of one
#     He will not shall be loathed,
#     O, left you do th'  Together sweet maysh to-night, thou shalt see a bare;
#     And sent foolish the allest oracle,
#     On draws are honour, sir! your own assistance;
#     And follow him alone doth see him and a shame be now, that you
#     do rid is no voice;
#     Stain'd up a tawn but in service
# </Ash>
# <Brock>
#
# Cycle 23
# Epoch 1/1
# 120384/120384 [==============================] - 236s - loss: 1.3275
# <Brock>Hark! The herald angels sing, Gloucester, and at his debate it speaks
#     wife; not well shall be hunt. Why prayers in myself
#     Both a bark f how I come
#     To die it into myself; and the burying of the
# </Ash>
# <Brock>He's not tance,
#     Those extrame braws confounds to proteus
#     Whither could I puffer for; their ring
# </Brock>
# <Ash>But a false bed! Is not the will proud he's gone up to Rome's, person these justice of all his own- the
#     garden set in our time; before that none upon your mean her jest. Sir.
#     Is he hath engag'd to told you both a sweet uncle and missing this inconsider
#     Has death of us a vex to the gentleman cannot hear me:
# </Brock>
# <Ash>Thou hast not deed me.
#   KING RICHARD. He's like law.
#     What, art thou shap'd, or with me; nones
# </Brock>
# <Ash>I know his desperate of speeding woe, but his complexion out, there is
#     by join'd fresh the best proceeding late; were not,
#     Conspiral she shall follow you are brought. St virtue
#     Was along a game with any gamestiry is our lock that we will be most man.
# </Brock>
# <Ash>
#
# Cycle 24
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3265
# <Brock>Hark! The herald angels sing, Gloucester, no brows upon the matter,
#     Yet you have stale of guiding this life
#     After, sir, ghost I pray you for this:
#     Let's give your foot-foulselves and make him thou my horns as the greater shame- at my side, here is no little; but that we should become no woman.
#     To way a lyouth in the time. I am unworth; and
#     Most speaking of my end of h    Dinners now are I speak again, and the blind; nothing to the reach,
# </Ash>
# <Brock>How does good appeal but
#     him jarky of money are all so hungly, at his palm, on me,
#     They oracle is fair counted more desire,
#     But if all our pleasure too much by a viguming art-
# </Brock>
# <Ash>My lord, how dead in indeed. I will cross too could go. I hear them from the penitence in kiss
#     Being once so general bloody from Thurio;
#     Ever under you this maid, ring that is, rade her free brush'd- out, and all
# </Brock>
# <Ash>All brings her drawn itself are portunes
# </Ash>
# <Brock>'Tis need, though I am not so,
#     Upon,
#     And honour of it, fault impire with scorn shade alive,
#     To my most her. Art thou no, I do bear,
#     Nor er the King, like this sense for,
#     That maiden h>
# <Brock>
#
# Cycle 25
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3254
# </Ash>
# <Brock>I have heard the man,
# </Brock>
# <Ash>Are you an act! Here comes to curse
#     Which indirectives his rastard, and daster first to the pedre.
#     I did be flies of sleep in a holes of the espies
#     same
#     With a wood-company called and bring you hang through since I quest
#     The ses of something this dog,
#     Can lost the hateful my father, of my sun
#     Is no more be rest that way upon to th' longer; good gill the direct
#     Hath made as into your wife! Look the prove in this mother's emity he think the sepose withal-weather'd- our house, that you who's.
#     They have said are too wasted to all- which I have build a livery swear
#     He knows her soul's welcome, or such innocent son
#     hung that I will trust him, and sie for our elder than made thee many ungentleman--
#     such griefs; and which is the great old rejoicity with myself, who smooth her for my handship like a man shall have but
#     Even in boars her. Their first shall have no good morrow,
# </Ash>
# <Brock>Not I, my dream,
#     Observation, and all his mind? Though the Queen, your eyes, my palb move shall my daughter,
# </Brock>
# <Ash>Speak! a tan benefit
#     With her veirs do creature thy mind
#     That they are shown down to my heart,
# </Brock>
# <Ash>

# %% [markdown]
# **IDEAS**:
# - use training corpus as dictionary to correct 'high confidence' spelling mistakes
# - gen_length -> num_lines
# - more emojis?
# - always throw out the first line of dialogue?

# %%
save5_path = model_path + 'shakespeare.h5'
if not os.path.exists(save5_path):
    model.save_weights(save5_path)
model.load_weights(save5_path)
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
run_epochs(model, 25)
# Out:
# Cycle 1
# Epoch 1/1
# 120384/120384 [==============================] - 236s - loss: 1.3582
# </Ash>
# </Ash>
# <Brock>O, how may I, for her king, 'tis bear to pronounce of your poot
#     Richard. Therefore 'call the old feed
#     her be, let's servant fortrock>I have seen to the matter;
#     Pass! I know their eye of Tybalt to be all the the full of privy, I
#     right upon my lord? I'll have honour of by the To your love; I waken a course of measures that cross unspeak their modesty,
#     The sake yet more great wilding equiral wrought
#     To the waist mielb, iron-farewell, for perform'd,
# </Brock>
# <Ash>The dearest that hath there a hApe the stay-loss, from this father in smiles of
#     sickness in angel
#     Confess'd. She be your mind courtesy,
#     So cot for things into them,
# </Brock>
# <Ash>Here, sir,
# </Ash>
#
# Cycle 2
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.3483
# <Brock>Hark! The herald angels sing, Gloucester, stay with myself.'
#     Nothing a   Forth answer appear.
#     I am stinz'd ajoin again.
#     I have were the uncle, speaks with men; so then onurance
# </Ash>
# </Ash>
# </Ash>
# <Brock> [Aside]  What's Great Prince's tongues under on the ingshapes and goodness and fire from the passing that has a look
#     I'll part it
#     she shall protest him, of their lips
# </Brock>
# <Ash>Do your Highness; but you look
#     That it true thee,
#     If you a dear son
#     Is the baslains not, and stays you kept, and I shall not she.' A loss couple of
#     Prize; with him owe it that her has made a cheek fall and chaste thee,
# </Brock>
# <Ash>
#
# Cycle 3
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3439
# <Brock>Hark! The herald angels sing, Gloucester!
#     I'll be much kinds of your trumpet- I must be courage.
#     Tutle that do let a great breeding rainly fits.
# </Brock>
# <Ash>We will do't Armedicinous battles
#     Whose earth-made thee asf>
# <Brock>Blas cannot be my whence.
#     How have I not solicit my hand of
# </Ash>
# </Ash>
# <Brock>If they are any man. O, sir, this mou in the
#     brother for me, I deserve away- following,
#     And I think she spar'd where you were recount to
#     bid us chyes? I would pardon her base soul! the
#     aless of him. Remember,
#     Not your breath with me;
#     Yet he affection'd in that prelictions, nature
# </Ash>
# <Brock>
#
# Cycle 4
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3414
# <Brock>Hark! The herald angels sing, Gloucester? all the orgo that
#     Some,
#     And so should follow his midation, what slight news all his son,
#     Her half breath of the change unto take your parties treason
#     Although been weary hoses
#     As to his title thick of one from your honour, too three
# </Brock>
# <Ash>Nothing, hear him
#     by your pand in strife
#     With hands that is some man, the Duchess where o'er with me, of words! Yet even your remembrance
#     Against it here a little fill, but I could rather befall
# </Brock>
# <Ash>I have great a notice? Therefore, my food,
#  the
#     approach; for she hath sing to I
#     very go f leave them after gold, boy, Queen.
#     Thou patient in thy peace; it is in this light,
#     And all frowns come to arm'd affright; so will the not- I do you
#     get yours, my
#     carried patience bromedgest cunning
#     Worthy kings are no funglish
#     To the world- she had some lap
#     To hear you'll past me when I coz adventure with a sound let his means, but
#     I do account your son. 'No, madam, I am at my love-not thought, content
# </Ash>
# <Brock>Come, how now, beginning the practice does as you
# </Ash>
# </Ash>
# <Brock>
#
# Cycle 5
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3393
# <Brock>Hark! The herald angels sing, Gloucester, who, not to be
# </Brock>
# <Ash>Even all good Execution- yet,
# </Ash>
# <Brock>Come, my lord,
#     Long Lucius: that we can offend them like a goodness; loed
#     As 'twere not as but here let us deform to predom. But fellow point, to wait it but a brat monster. Never thrust me? From the horse I have the creature
#     In blessing walking of seize, go, that harm to remember the fellow. The
#  lack. Now destiny, Jew; for where;
#     But out of the powers and her. King, madam, you would love my beasts as desert,
#     May, and hauld not come without, sir, too much to my town-marriage
#     Most touch attine cryest old more
# </Brock>
# <Ash>If you strike a dance of Richmoly afters
#     think where pieces of grey fellows,
#     Purpose out of friends, your servants were a merries from all o'er his particular bloody
#     Do bear a moint: Lavinia, the powers
# </Brock>
# <Ash>Then when to stand it was thine, guilty, to the working honest-more thoughts
# </Brock>
# <Ash>
#
# Cycle 6
# Epoch 1/1
# 120384/120384 [==============================] - 236s - loss: 1.3374
# <Brock>Hark! The herald angels sing, Gloucester,
#     But if you not meet to see your speak this
#     the heart
#     pursuion! I'll to you, and with men such blood alone
#     wrangles by but our pays
#     but thank
#     I have lost did prove out of my putting
# </Ash>
# <Brock>Nay,
#     Which doth be at whom with a strate. You have am bird with our sir,
#     When the pail were so put into locks his hands, though false gits of th' woenger. Well, let me
#     cannot demandly, how it is liv'd.'
#     The pretty field of tress'd and earth of the breath airnish'd his reverence,
#     And let him cunning the profound of Patience to true suits
# </Ash>
# <Brock>Take that these sun for estate to fear, sir,
# </Brock>
# </Brock>
# <Ash>Or nothing we are one desire
#     The pistolim of feelless gravemn'd. Against a death,
#     Whose word, give heaven-buy have we put a sin yet
#     The sweet royal tongue that I know our fool I some offence; but at the sceptre
#     assure his father; but then the sight
#     In the words are vile much unyour precious part I cannot welcome to seem the Lord's fitures twain the way-
#     But cannot inbanish it.
#     Loving the crown the lice apes, for I
# </Ash>
# <Brock>
#
# Cycle 7
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.3355
# </Brock>
# <Ash>Question and love which you know you
#     By joyful wicked:
#     nence this tongue
# </Ash>
# <Brock>Afflicture from the Living roarer, for
#     As no first thought too, but 'twere like the money, I three?
#   Rom. This sadly puck.
#     Such the issue and speed, sir;
# </Ash>
# <Brock>Quote as answer shall have been unbeardier. What might
#     lodg'd to the hard; if thou hast men's love; not plot
#     but with call thee; the very good matter's stun.
# </Ash>
# </Ash>
# <Brock>
#
# Cycle 8
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3341
# <Brock>Hark! The herald angels sing, Gloucester,
#     Very flies
#     To the man with fellows i' th' fault,
# </Brock>
# <Ash>I will be more I beg   Just, because it cannot smell, open me and sweet Oneryhanking by the smell; for other child;
#     Before say you her edity. Nor is a prayer- it is your friends in a groat earth three hovers;
#     Put upon the first cuckold lowlands
# </Ash>
# <Brock>Holy
#     ears; for you have, sir, by the fools
#     And show'd, the noble fear to me. Let offend himself a weary
#     Even so much more hand no more to be forshear but news, for I do,
# </Brock>
# </Brock>
# <Ash>No, all sometimes and the rage
#     As I must were as something heard, his happy great delicards and rem'd with me.' I'll make us cry; and serve us to be true;
#     It is a man of her sorrow be gone?
# </Brock>
# <Ash>
#
# Cycle 9
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3327
# <Brock>Hark! The herald angels sing, Gloucester. O these tears both the mind, or thou.
#     The brook of his mind?
#     I will answer the fearing the doilent for a man
#     They laugh of and her, poor
#     lady-king,
# </Brock>
# </Brock>
# <Ash>I would will keep them out is long! Thou go'st the sun?
#     How, so this policy, I must past on, and a grand
#     Exceeded them
#     Till his part-have grace but my lord, that I am away,
#     So seem to prison him lips
#     This meaning it to the judgment of the view the hird
#     Yours!'
#     To sight by this slain,
#     My discharge it should be a learning place
#     Will be imsuade, dsteal wax so some
#     robbs, of charmstone,
# </Ash>
# <Brock>Good, beg have it past, of it. Ay; it shall not lie
#     the weight. Look lord; 'tis the fear;
#     Here, if 'tis and cast no more, there's the Queen,
#     'Itheir words for our lord!
# </Ash>
# <Brock>By th' Princely coin, good my necks to-morrow in
# </Ash>
# <Brock>
#
# Cycle 10
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3312
# <Brock>Hark! The herald angels sing, Gloucester, in the peace. How now, get them but a true lord, a bride; and all the lie
#     To be done ime of humours renew-heart; as more than thine own bhot.
#   FIRST LORD. Have they you have hang'd
#     Of his fudges, and come,
#     And so much upon the ladyship; peace, no more is touch'd inquired,
#     Dismiss'd, his leaning levish'd with a
# </Brock>
# <Ash>The pleadamentable such
# </Brock>
# <Ash>Here's not England, and so might,
#     So much there to be as the past rest may roar of men,
#     For they speak from me; for he was
#     authority do,
#     Pity you, but if he had but a rawn.
# </Brock>
# <Ash>My goods! When I thank thy foads. We are sharp contempt you held him with this. Whom that I fear? I stly lend us?
#   SIR TOBY. Respect them there,
#     But 'twas not pride to shide at mire
#     had he spoke to lost I to know most alsworn to be showing.                                              No sands are no heard to be demetrius
#     Or cast that this shall be stood but
#     twelveing the other, but tave it done;
#     and may be compares so defend his eyes
#     As are profitable by this second of my lord;
#     Who would take the human gentlemen
#     Than white personals of alconsence, and make yours; the Julia; there's be oubided. She cannot be thus the case
#     To crown to the meeder; if I could so't
#     is the large but earth
#     To make amission at a little great son. Before you
#     promise thee on her glove,
#     This terror for't, being breath'd
#     bid him know for her. What?
#     I'll get you, owe with him, r;
#     Her master might know
#     may be like a spinity; as much he was. I will, Admirable honour is no pleasure of great as ignoble; and hermint, being does him,
#     For accus'd his earth diest; therefore
# </Ash>
# <Brock>Then your ph is a Greek was study
#     Much things of our ckept in their life, for profession
#     A limbrief-
#   KING RICHARD. In all things. No may in't,
#     You have not pass'd to put it.
# </Brock>
# <Ash>
#
# Cycle 11
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3306
# <Brock>Hark! The herald angels sing, Gloucester,
#     Whose suit
#     Well; there is a crollif thy son, good lord,
#     When Verona; for where we hide thyself should else you can tell you. [Knocking]  To coms and sings with a secret door
#     vessel
#     Endure, and o'ernear yet the heels, and thou mistress your poster,
#     grow on this understand in fught,
#     Whether the soldier of our mistress be behind her. Can you hear his wife,
#     it is none nature of priest
#     And think then ourselves! Jove o' amazed thee, that there's glad,
#     Compass in his villain; though
# </Brock>
# <Ash>Nay, a wit cell off, potent friend-
#     Unfand that they will not hear all
# </Ash>
# <Brock>Here comes an obedience will plead the Queen lay with event,
#     Chenur is not so
#     Profitable that to see that he smiles! Good master Sir Prince, some were a thousand perfection's son- to be parted and desp'rate welcome to me;
#     All modesting to now, and let's then like false calm
# </Brock>
# </Brock>
# <Ash>Nay, and dispinion see, no man's heart of-house
#      I must equest, whom the rest, his choice.
#   Wor. If I needs forgive it with a kind of Reigh
# </Ash>
# <Brock>
#
# Cycle 12
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3296
# <Brock>Hark! The herald angels sing, Gloucester, from the towns in queen. I think why I have gone, not I. Once
#     skeeping, whuric and tastes, name and sith thee
#     The couple fellow ine
#     That prepar'd you make them be again us;
# </Brock>
# <Ash>Mistress Shall he hang'd- I'll be am made this same sun,
#     But, morrow, no more. Some blement
#     Damned the wise is envy
# </Ash>
# <Brock>'Brief rejoices appear.
#     Then I threat
#     The former put in an oath
#     Seeing not-a deitess of these other faces,
#     Or, may be so, and let me concern,
#     To depend it with reproigh! Varria,
#     how this that heaven we were not hang'd, my lord- for a poison does again this thrust my northronace here
#     such lain thou strikes, to the heaven, sit-
#     And I have ploughing on the friendrock>Take no her sight
#     do behorrier, wilt so, now he was not or his osure, sir, now
#     save a lord. Then, the base of a broilers she lie; give him heaven to be lam'd
# </Ash>
# <Brock>These contrary been a ship of the day,
#     So for my beauty of the idle themselves
# </Brock>
# </Brock>
#
# Cycle 13
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3282
# <Brock>Hark! The herald angels sing, Gloucester,
#     Or be not about your life, the lust t you are to his niece, if I are in favours may say 'I may not, as though I am down barish'd feet;
# </Ash>
# <Brock>O good wife, good felliage, besides, on the
# </Ash>
# <Brock>A chapacle
#     When I think it is forward's rounded, the necks
# </Ash>
# <Brock>This blown her love been!
#     Fit him:
#     When I hear not- sir?
#   Par. I tremble the And deed wherewill not long to his mind of
#     About thy neck, so we
#     wear your hearted poor braves; I
# </Ash>
# <Brock>Now, sweet. No azon, the sun,
#     Mean with him well-unlulfr church of the which he was
#     heard nothing, and chamber her light, like ais mountains and this. If courage,
#     oak backwho sacred and seven where you
#     must have unto the other duty of his cause as he not
# </Brock>
# <Ash>
#
# Cycle 14
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3277
# <Brock>Hark! The herald angels sing, Gloucester, keep thy brother's master.
# </Ash>
# <Brock>Ingall-lubs, offer ock>
# <Ash>Odegrees; when no man with bolds of you have not little Cardinal,
#     One notes, and
#     sirs for the the chronicles exquest you.
#     Might desire you not to see yourself in the shadow,
# </Brock>
# <Ash>Welorvolion laughs of your knife
#     Are shrikish'd in such, go so him. Her kissing mistress, I would you all,
# </Brock>
# <Ash>I furnished twife Drum what made you of bull;
#     And though they case to cheer. Your good ravia swains of our soul o' th' royal mother.
#     The mean be true. What it is much savage for me,
#     Dances curst thee forl and under great Neptune and now but
#      and the next, coat to her purpose and nought- she should suffer him upon him defuse, sir,
#     I know not in the benefally, if you never stage
# </Ash>
# <Brock>
#
# Cycle 15
# Epoch 1/1
# 120384/120384 [==============================] - 239s - loss: 1.3265
# </Brock>
# <Ash>What so torn some as all stronger eye,
# </Brock>
# <Ash>Camillo
#     By my moving of honest gallant conclusion
#     The enemies I may spurn infect,
#     Behold thee, and under my woe, your appent
#     Send you bare, your letter besoldiers reason,
# </Brock>
# <Ash>I must not stay as with his great bed for your air;
#     The heavenies, and whose chapot love,
#     The horse-her. How now, good mine honest charge; curse of our lordship,
#     And nature of your wit many charity, that 'em I have an act in honour-
# </Brock>
# </Ash>
# <Brock>
#
# Cycle 16
# Epoch 1/1
# 120384/120384 [==============================] - 235s - loss: 1.3259
# <Brock>Hark! The herald angels sing, Gloucester, wey, if thou most nothing
#     of misery please his word, where I have infactary to while much no fantasic, it with you.
#   Mer. Bear a mean news stain no in't; all such
#     So mine own life. Is not such more honest very ladies,
#     Your lordship kill'd in death to the speed
#     Plucket the guard again the dull of the citizens
#     Than another hame be reverence of England
#     That one of this coals;
# </Ash>
# <Brock>My lord, boy, damn'd by drink-
#     I have our master noble throats are this lover's man's sheep.
#     Come he grew from me; I must become his cousin Masquite; but then hath her and all the puril and our pair
#     Pardon her extreme of the gold; for our empty   'By late bewain'd  your father
# </Brock>
# <Ash>We know to say that become upon your hunts
#     Which you soon the man good, these keys are a custom I like a chartful good cause, one of old Lord These
#     Fellows into the place; not ofts
#     To come inhingou person, I have persons,
#     And if one and swelling mine
#     Do but greet him charces to-morrow
#     'Tis not your bodiece for my t comes an hour, upon some and young infly is
#     a prophecience of scey way be things from him.
# </Ash>
# </Brock>
# </Brock>
# <Ash>
#
# Cycle 17
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3249
# <Brock>Hark! The herald angels sing, Gloucester's child,' and think you,
#     In the grave with the I perfection
#     Look your gracious sweet,
#     Warrant you so farewell.
#     Look you to her the strong ras but to
#     word to speak. Embort!
#     Mine? Do't him that make her tree. I pray you what she your news: what these country, your soul kills doth I house her women
# </Brock>
# <Ash>Tell me to your wish'd!
#     No, nothing
#     Whisper ourselves are o'er thee, new mind, but as I may cry on it. Now and
#     for all that, so call a death
#     Hands
#     Our beauty, to make my wife, O speeds to speak it out; upon as
#     Handing to as
#     replained for himself a respect of other; this on the
#     Jeunck>
# <Ash>No, no ormanting purpose of her
#     lady, as we can city as the slave; you dare grow
#     angry strong in reverend false
#     Heart his heels being friend
# </Brock>
# <Ash>What's thus a one of powers have think'd you to him,
#     We take a duty and all the Priam and such much fresh obstears were his common sons!
#     Thou hast what is weddived to th' more. Ah, their port to see the dured King,
#     Most since one he come thereleason! I'll wak'd
#     And fair wild touch'd not go from with such was deliver to request it of her
# </Brock>
# </Ash>
# <Brock>
#
# Cycle 18
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3245
# <Brock>Hark! The herald angels sing, Gloucester.
#     They say now. But back;
# </Ash>
# <Brock>Come, have no less you clear them hither; so foolish
#     the prodigal fault of my her cannot have, let us reckous
#     That the mighty dread of
#     hence. Have thou noble unpuckets, one sad
#     So her pardon shows his honour and but time; and your very rock>
# <Ash>And hath my kind of the robberiest boy
#     fay out, hither give us this palace his they'll have sing of courses of the name,
# </Ash>
# <Brock>Where do you seem your wrong-weeping, cousin appears
#     Rack you in, and other trumpet, it is, for you, which root's ducats-
#     There's might, she will be a friend
# </Brock>
# <Ash>Now, sir. It is the ther here.
# </Ash>
# <Brock>
#
# Cycle 19
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3234
# <Brock>Hark! The herald angels sing, Gloucester,
#     Good Mistress From Pisa, good speed, how dost thou im
#     Cur not one, an her sheeping of
#     entertain,
#     And know forth to me or another.
#     Go, I might tell you, keep you heard; and what one him have I given lov'd
#     Like merit us, anon, and upw so forsake upon me, and substance;
# </Ash>
# <Brock>For what's the boots, and I have stick, uncle of this
#     With him, and see, was not done
#     Have you wear you but our sea, children, that I, when he can be will
#     or a happy rude see the time at rock>Nend, and first more
#     Because not indeed, and rang these gentleman's offender,
#     Whom
#     And then had she she mean then by scarce he
#     see to him, tell me
#     He then though I have heard to thy but thence is oscompany;
#     If thou art told me, the King comes fashion, as he worse perform
#     Seems; in to my letter the
#     blood of armies
#       If led; you speak all some
#     fair advise of thine. The purpose-business of my man,
#     Now from you on't, thy daughter, my lord,
#     Or for your daughter'd, by them and folly to give my closekiss now
#     Which I told me to spury fonth. Take us out; I would then know
#     To you were well,
#     The near from scopes to strumpets, unaboard so, welcome a kind of his
#     thousand life look and not you, before he men may not
# </Ash>
# <Brock>And he shall burn, be fear nothing; alhat welcome so much of world,
#     May say you that in you, I have. Were I
#     have the displeasure. This face is not betray
#     above th' time than sometime, thou art. No father shall conquer'd;
# </Brock>
# <Ash>No more doth to e I tell thine unnew
# </Ash>
# <Brock>No, they think so; come, sweet youth
#     Than children have coament courtesy, confess me with her; if he not
#     no affairs; and my thousand water with thy face, if he be well followed,
#     I saw your minds is credit.
# </Ash>
#
# Cycle 20
# Epoch 1/1
# 120384/120384 [==============================] - 236s - loss: 1.3230
# <Brock>Hark! The herald angels sing, Gloucester! Into the heart. kill me. What would the what you are
#     least were to pray mine eye: because we think our encountryman, that so, set at the repast!
#     Less I be repairing her matches to't,
#     To curiousn from my hands;
# </Ash>
# <Brock>Further I do beseech your tongue to business of this most book of his heart:
#     This satisfied worthy cold nights the
#     Most labor circumstance therefore; their bed weary cunnings.
# </Ash>
# <Brock>My youth of Norfolk, to
#     cheer to the which is much I think
#     score, last ever to weep;
# </Brock>
# <Ash>Good goodness! If you have fight off therefore, deny
#     The Proformance
# </Brock>
# <Ash>O, how think it buy. Lest I think off
#     How by their bestow of courageman; then I know my lord. Put this
#     slow Souls before cold all the Token soul- my sun
#     Of their l
# </Ash>
# <Brock>
#
# Cycle 21
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3224
# <Brock>Hark! The herald angels sing, Gloucester,
# </Ash>
# <Brock>Why, he that I is not, and not for me
#     Condition of breath
# </Ash>
# </Brock>
# <Ash>How could not all which have hath sneed to his those book-wealth;
# </Brock>
# <Ash>Th' arpose I say I say.
# </Brock>
# <Ash>
#
# Cycle 22
# Epoch 1/1
# 120384/120384 [==============================] - 237s - loss: 1.3213
# <Brock>Hark! The herald angels sing, Gloucester,
#     Thy tidings like a worse of this nome of her. One Apemantus,
#     Child says this- ever
#     My space, when to lay of our soul- in goat, make no care
#     For him; I did be side. Here it begins for them
# </Brock>
# <Ash>Your offices lie to hear; they hell.
#     Inding me unlet a fire of his people!
#     One honest ear-welcome not mewith what would we mot imagination
# </Ash>
# <Brock>I am alell'd, and she would chide, and shall meseward
#     wretched, sir, must have nold life done incentions? And offer
# </Brock>
# </Ash>
# <Brock>But, look you- I take shall action shall be many dogs
#     her cry when you resuming by
#     A thousand souls and cut from
# </Brock>
# <Ash>
#
# Cycle 23
# Epoch 1/1
# 120384/120384 [==============================] - 240s - loss: 1.3210
# <Brock>Hark! The herald angels sing, Gloucester, and yet comes thy shepherd's now-carm of pesteries uncle. Yes. this heir?
#   SECOND GENTLEMAN. Come, to do it of me. oversweet son, roots, fled
# </Ash>
# <Brock>I read by mine be proud off,
#     Let him read not at His
#  and
# </Brock>
# <Ash>False to a kind
#     brow, but a flesh of 'a throng. Ere you cho lord! Sometime are no charity-
#   FIRST LORD. Most partly so held thee, is much of any thought; then 'tis such another; which dare him be but a both ignorant; she has he reason of mine,
# </Brock>
# <Ash>Well, fie will see them black The ides. Then I prithee be, now to your name;
# </Brock>
# <Ash>Prithee now, by your gracious precious servants
# </Brock>
# <Ash>
#
# Cycle 24
# Epoch 1/1
# 120384/120384 [==============================] - 238s - loss: 1.3204
# <Brock>Hark! The herald angels sing, Gloucester,
#     Knave of kings more than Julia, to chide unto our higher's corner,
# </Brock>
# <Ash>The next infection of leave. I'll not speak
#     your court, in a child? I hope when he was in these things
#     doth please your Roman as joble;
# </Brock>
# <Ash>Well, not into this children true;
#     When to make no ear of your penhat wear a pomper-sh>
# <Brock>See, sir! that I have
#     of patiences are added sirely when tree
#     Knowing but heath than she did beggar,
#     Bemonior in all the time. Set thee to the first shoady. Let me
# </Ash>
# <Brock>I was the dear incur
#     the law blows weaking about the
#     meat
# </Brock>
# <Ash>
#
# Cycle 25
# Epoch 1/1
# 120384/120384 [==============================] - 239s - loss: 1.3200
# </Brock>
# <Ash>I would are a sir, for, of sir- we shall present the was such
#     Of complexion in wise soul; nor
#     The your master dead esteem her own business;
#     I will not something. Ath, full offwater,
# </Brock>
# <Ash>My liege, laugh, you pillow put on French was kill'd, for jaster's low about this,
#     And here!
#     How but to a pair was judgment
# </Brock>
# </Brock>
# </Ash>
# <Brock>

# %%
save5_2_path = model_path + 'shakespeare_2.h5'
if not os.path.exists(save5_2_path):
    model.save_weights(save5_2_path)
model.load_weights(save5_2_path)
